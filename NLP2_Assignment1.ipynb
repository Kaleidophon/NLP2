# %%
f = open("training/hansards.36.2.e", "r", encoding="utf8") 
english = f.readlines()
f.close()
f = open("training/hansards.36.2.f", "r", encoding="utf8")
french = f.readlines()
f.close()

# %%
# kon niet echt een mapping vinden tussen de zinnen dus ik neem aan dat de zinnen op volgorde staan in de files? 
translations = list(zip(english, french))
translations
# Out:
# [('36 th Parliament , 2 nd Session \n',
#   '36 e Législature , 2 ième Session \n'),
#  ('edited HANSARD * NUMBER 1 \n', 'hansard RÉVISÉ * NUMÉRO 1 \n'),
#  ('contents \n', 'table DES MATIÈRES \n'),
#  ('Tuesday , October 12 , 1999 \n', 'le mardi 12 octobre 1999 \n'),
#  ('opening OF THE SECOND SESSION OF THE 36 TH PARLIAMENT \n',
#   'ouverture DE LA DEUXIÈME SESSION DE LA 36E LÉGISLATURE \n'),
#  ('oaths OF OFFICE \n', 'les SERMENTS De OFFICE \n'),
#  ('bill C - 1 . \n', 'projet de loi C - 1 . \n'),
#  ('introduction and first reading \n', 'présentation et première lecture \n'),
#  ('right Hon. Jean Chr é tien \n', 'le trèshon. Jean Chrétien \n'),
#  ('speech FROM THE THRONE \n', 'discours DU TRÔNE \n'),
#  ('the Speaker \n', 'le Président \n'),
#  ('the Right Hon. Jean Chr é tien \n', 'le trèshon. Jean Chrétien \n'),
#  ('vacancies \n', 'vacance DE SIÈGE \n'),
#  ('York West \n', 'York - Ouest \n'),
#  ('the Speaker \n', 'le Président \n'),
# ...

# %% [markdown]
# # IBM1 EM Algorithm

# %% [markdown]
# # IBM1 Variational Inference

# %% [markdown]
# # IBM2
