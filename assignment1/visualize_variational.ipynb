# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
ll_0_001 = [-2328349.1990779643, -570686.3030220084, -325563.8281453881, -396679.16474164027, -336506.395825127, -287346.6621000834, -270617.5395888112, -262579.609513732, -257600.0268781855, -254250.72172832568]
aer_0_001 = [0.5021097046413502, 0.5163674762407603, 0.523961661341853, 0.4956709956709957, 0.48630887185104055, 0.48123620309050774, 0.47619047619047616, 0.4761376248612652, 0.47491638795986624, 0.47268673355629875]

# %%
ll_0_01 = [-1596712.516525647, -943393.9810142887, -824253.3173531262, -862797.6736980289, -820621.1851958184, -804959.999610901, -798162.7001477175, -794495.5856482862, -791602.5274029183, -789580.5329512525]
aer_0_01 = [0.49683544303797467, 0.5100316789862724, 0.5210526315789474, 0.48783068783068784, 0.48305084745762716, 0.4751322751322752, 0.4699049630411827, 0.46786090621707055, 0.46786090621707055, 0.46786090621707055]

# %%
ll_0_1 = [-10668876.642402956, -10527668.150953176, -10486356.129512109, -10469925.949053308, -10461792.342400094, -10457217.933824986, -10454390.779069642, -10452576.42767566, -10451344.358249953, -10450432.326351821]
aer_0_1 = [0.4561586638830898, 0.4560669456066946, 0.4412997903563941, 0.4367816091954023, 0.4311064718162839, 0.42946708463949845, 0.4252873563218391, 0.42198952879581153, 0.37461928934010147, 0.37461928934010147]

# %%
ll_1 = [-148601297.90423548, -148618409.92134237, -148614122.16952088, -148611670.8005346, -148610545.54754663, -148609711.39502135, -148609293.54391408, -148608967.82834828, -148608788.90832773, -148608645.4312062]
aer_1 = [0.7249747219413549, 0.5052410901467506, 0.5010482180293501, 0.4726890756302521, 0.47163865546218486, 0.46113445378151263, 0.41260162601626016, 0.41158536585365857, 0.41056910569105687, 0.41056910569105687]

# %%
plt.plot(ll_0_001)
plt.plot(ll_0_01)
plt.plot(ll_0_1)
# plt.plot(ll_1)
plt.legend(['alpha = 0.001', 'alpha = 0.01', 'alpha = 0.1', 'alpha = 1'], loc='best')
plt.show()

# %%
plt.plot(aer_0_001)
plt.plot(aer_0_01)
plt.plot(aer_0_1)
plt.plot(aer_1)
plt.legend(['alpha = 0.001', 'alpha = 0.01', 'alpha = 0.1', 'alpha = 1'], loc='best')
plt.show()
